# %%
import pandas as pd
import seaborn
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv("C:/Users/a/Desktop/covid_19_india.csv").drop(columns = 'Sno')
data.head()
data.describe()
plt.figure(figsize=(5,5))
seaborn.heatmap(data.corr(),annot=True,cmap="RdYlGn")

# %%
district=pd.read_csv("C:/Users/a/Desktop/district_wise.csv").drop(columns = 'SlNo').drop(columns = 'Last_Updated')
district.head()
district.describe()
plt.figure(figsize=(10,10))
seaborn.heatmap(district.corr(),annot=True,cmap="coolwarm")

# %%
hosp=pd.read_csv(r"C:/Users/a/Desktop/HospitalBedsIndia.csv").drop(columns='Sno')

# %%
hosp.head()
# Out:
#                     State/UT NumPrimaryHealthCenters_HMIS  \
# 0  Andaman & Nicobar Islands                           27
# 1             Andhra Pradesh                         1417
# 2          Arunachal Pradesh                          122
# 3                      Assam                         1007
# 4                      Bihar                         2007
#
#    NumCommunityHealthCenters_HMIS  NumSubDistrictHospitals_HMIS  \
# 0                               4                           NaN
# 1                             198                          31.0
# 2                              62                           NaN
# 3                             166                          14.0
# 4                              63                          33.0
#
#    NumDistrictHospitals_HMIS  TotalPublicHealthFacilities_HMIS  \
# 0                          3                                34
# 1                         20                              1666
# ...

# %%
hosp.corr()
# Out:
#                                   NumCommunityHealthCenters_HMIS  \
# NumCommunityHealthCenters_HMIS                          1.000000
# NumSubDistrictHospitals_HMIS                            0.975144
# NumDistrictHospitals_HMIS                               0.991807
# TotalPublicHealthFacilities_HMIS                        0.996703
# NumPublicBeds_HMIS                                      0.993827
# NumRuralHospitals_NHP18                                 0.980310
# NumRuralBeds_NHP18                                      0.992747
# NumUrbanHospitals_NHP18                                 0.986058
# NumUrbanBeds_NHP18                                      0.987193
#
#                                   NumSubDistrictHospitals_HMIS  \
# NumCommunityHealthCenters_HMIS                        0.975144
# NumSubDistrictHospitals_HMIS                          1.000000
# NumDistrictHospitals_HMIS                             0.970896
# ...

# %%
plt.figure(figsize=(10,10))
seaborn.heatmap(hospital.corr(),annot=True,cmap="coolwarm")
